# %%
import pandas as pd

# %%
raw_data = pd.read_csv("C:/Users/Administrator/Downloads/Automobile_price_data__Raw_.csv")

# %% [markdown]
# #### 1. Pandas Basics

# %%
raw_data.head(2)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
#
# [2 rows x 26 columns]

# %%
raw_data.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 200         mpfi  3.78    3.15               9.5        114      5400
# 201         mpfi  3.78    3.15               8.7        160      5300
# 202         mpfi  3.58    2.87               8.8        134      5500
# 203          idi  3.01    3.40              23.0        106      4800
# 204         mpfi  3.78    3.15               9.5        114      5400
#
#     city-mpg highway-mpg  price
# 200       23          28  16845
# 201       19          25  19045
# 202       18          23  21485
# 203       26          27  22470
# 204       19          25  22625
#
# [5 rows x 26 columns]

# %%
raw_data.shape   # shape returns tuple of size of rows & columns
# Out:
# (205, 26)

# %%
raw_data.columns   # returns column names
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
raw_data.isnull()   # isnull() returns True for missing data cell, False means no missing value.
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0         False         False            False       False  ...        False
# 1         False         False            False       False  ...        False
# 2         False         False            False       False  ...        False
# 3         False         False            False       False  ...        False
# 4         False         False            False       False  ...        False
# ..          ...           ...              ...         ...  ...          ...
# 200       False         False            False       False  ...        False
# 201       False         False            False       False  ...        False
# 202       False         False            False       False  ...        False
# 203       False         False            False       False  ...        False
# 204       False         False            False       False  ...        False
#
#      fuel-system   bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0          False  False   False              False       False     False
# 1          False  False   False              False       False     False
# 2          False  False   False              False       False     False
# 3          False  False   False              False       False     False
# 4          False  False   False              False       False     False
# ..           ...    ...     ...                ...         ...       ...
# 200        False  False   False              False       False     False
# 201        False  False   False              False       False     False
# 202        False  False   False              False       False     False
# 203        False  False   False              False       False     False
# 204        False  False   False              False       False     False
#
#      city-mpg  highway-mpg  price
# 0       False        False  False
# 1       False        False  False
# 2       False        False  False
# 3       False        False  False
# 4       False        False  False
# ..        ...          ...    ...
# 200     False        False  False
# 201     False        False  False
# 202     False        False  False
# 203     False        False  False
# 204     False        False  False
#
# [205 rows x 26 columns]

# %%
raw_data.notnull()    # notnull() returns True for non-empty cell, False for missing missing value.
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0         True               True  True       True        True          True
# 1         True               True  True       True        True          True
# 2         True               True  True       True        True          True
# 3         True               True  True       True        True          True
# 4         True               True  True       True        True          True
# ..         ...                ...   ...        ...         ...           ...
# 200       True               True  True       True        True          True
# 201       True               True  True       True        True          True
# 202       True               True  True       True        True          True
# 203       True               True  True       True        True          True
# 204       True               True  True       True        True          True
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0          True          True             True        True  ...         True
# 1          True          True             True        True  ...         True
# 2          True          True             True        True  ...         True
# 3          True          True             True        True  ...         True
# 4          True          True             True        True  ...         True
# ..          ...           ...              ...         ...  ...          ...
# 200        True          True             True        True  ...         True
# 201        True          True             True        True  ...         True
# 202        True          True             True        True  ...         True
# 203        True          True             True        True  ...         True
# 204        True          True             True        True  ...         True
#
#      fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0           True  True    True               True        True      True
# 1           True  True    True               True        True      True
# 2           True  True    True               True        True      True
# 3           True  True    True               True        True      True
# 4           True  True    True               True        True      True
# ..           ...   ...     ...                ...         ...       ...
# 200         True  True    True               True        True      True
# 201         True  True    True               True        True      True
# 202         True  True    True               True        True      True
# 203         True  True    True               True        True      True
# 204         True  True    True               True        True      True
#
#      city-mpg  highway-mpg  price
# 0        True         True   True
# 1        True         True   True
# 2        True         True   True
# 3        True         True   True
# 4        True         True   True
# ..        ...          ...    ...
# 200      True         True   True
# 201      True         True   True
# 202      True         True   True
# 203      True         True   True
# 204      True         True   True
#
# [205 rows x 26 columns]

# %% [markdown]
# #### 2. Data Slicing
#     * loc() & iloc()

# %% [markdown]
# **raw_data.loc[row_label, column_label]**

# %%
# loc - Label based indexing: Using row & column names , data will be sliced
raw_data.loc[1:10]
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 1           two  convertible          rwd           front        88.6  ...
# 2           two    hatchback          rwd           front        94.5  ...
# 3          four        sedan          fwd           front        99.8  ...
# 4          four        sedan          4wd           front        99.4  ...
# 5           two        sedan          fwd           front        99.8  ...
# 6          four        sedan          fwd           front       105.8  ...
# 7          four        wagon          fwd           front       105.8  ...
# 8          four        sedan          fwd           front       105.8  ...
# 9           two    hatchback          4wd           front        99.5  ...
# 10          two        sedan          rwd           front       101.2  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 1           130         mpfi  3.47    2.68               9.0        111
# 2           152         mpfi  2.68    3.47               9.0        154
# 3           109         mpfi  3.19    3.40              10.0        102
# 4           136         mpfi  3.19    3.40               8.0        115
# 5           136         mpfi  3.19    3.40               8.5        110
# 6           136         mpfi  3.19    3.40               8.5        110
# 7           136         mpfi  3.19    3.40               8.5        110
# 8           131         mpfi  3.13    3.40               8.3        140
# 9           131         mpfi  3.13    3.40               7.0        160
# 10          108         mpfi  3.50    2.80               8.8        101
#
#     peak-rpm city-mpg highway-mpg  price
# 1       5000       21          27  16500
# 2       5000       19          26  16500
# 3       5500       24          30  13950
# 4       5500       18          22  17450
# 5       5500       19          25  15250
# 6       5500       19          25  17710
# 7       5500       19          25  18920
# 8       5500       17          20  23875
# 9       5500       16          22      ?
# 10      5800       23          29  16430
#
# [10 rows x 26 columns]

# %%
# column slicing using loc(), 'make':'wheel-base'
raw_data.loc[:,'make':'wheel-base']
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
#     engine-location  wheel-base
# 0             front        88.6
# 1             front        88.6
# 2             front        94.5
# 3             front        99.8
# 4             front        99.4
# ..              ...         ...
# 200           front       109.1
# 201           front       109.1
# 202           front       109.1
# 203           front       109.1
# 204           front       109.1
#
# [205 rows x 8 columns]

# %%
raw_data.loc[[1,3,4,7,9,10,11,13],['make','fuel-type','num-of-doors','wheel-base','width','num-of-cylinders']]
# Out:
#            make fuel-type num-of-doors  wheel-base  width num-of-cylinders
# 1   alfa-romero       gas          two        88.6   64.1             four
# 3          audi       gas         four        99.8   66.2             four
# 4          audi       gas         four        99.4   66.4             five
# 7          audi       gas         four       105.8   71.4             five
# 9          audi       gas          two        99.5   67.9             five
# 10          bmw       gas          two       101.2   64.8             four
# 11          bmw       gas         four       101.2   64.8             four
# 13          bmw       gas         four       101.2   64.8              six

# %% [markdown]
# **raw_data.iloc[row_index, columns_index]**

# %%
# iloc - integer based label indexing: Using row & column index position, data will be sliced
raw_data.iloc[1:10]     # start index = 1, end index = 9
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
# 5        sedan          fwd           front        99.8  ...          136
# 6        sedan          fwd           front       105.8  ...          136
# 7        wagon          fwd           front       105.8  ...          136
# 8        sedan          fwd           front       105.8  ...          131
# 9    hatchback          4wd           front        99.5  ...          131
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
# 5         mpfi  3.19    3.40               8.5        110      5500       19
# 6         mpfi  3.19    3.40               8.5        110      5500       19
# 7         mpfi  3.19    3.40               8.5        110      5500       19
# 8         mpfi  3.13    3.40               8.3        140      5500       17
# 9         mpfi  3.13    3.40               7.0        160      5500       16
#
#   highway-mpg  price
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
# 5          25  15250
# 6          25  17710
# 7          25  18920
# 8          20  23875
# 9          22      ?
#
# [9 rows x 26 columns]

# %%
raw_data.iloc[:,:]    # selecting all rows & all columns
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19    3.40              10.0        102
# 4            136         mpfi  3.19    3.40               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01    3.40              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [205 rows x 26 columns]

# %%
raw_data.iloc[:,2:12]    # slicing column by using integer index.
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
#     engine-location  wheel-base  length  width
# 0             front        88.6   168.8   64.1
# 1             front        88.6   168.8   64.1
# 2             front        94.5   171.2   65.5
# 3             front        99.8   176.6   66.2
# 4             front        99.4   176.6   66.4
# ..              ...         ...     ...    ...
# 200           front       109.1   188.8   68.9
# 201           front       109.1   188.8   68.8
# 202           front       109.1   188.8   68.9
# 203           front       109.1   188.8   68.9
# 204           front       109.1   188.8   68.9
#
# [205 rows x 10 columns]

# %% [markdown]
# #### 3. Columns Selection

# %%
raw_data['make']    # slicing one column
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: make, Length: 205, dtype: object

# %%
# selecting multiple columns by using column-list.
raw_data[['make','fuel-type','num-of-doors','wheel-base','width','num-of-cylinders']]
# Out:
#             make fuel-type num-of-doors  wheel-base  width num-of-cylinders
# 0    alfa-romero       gas          two        88.6   64.1             four
# 1    alfa-romero       gas          two        88.6   64.1             four
# 2    alfa-romero       gas          two        94.5   65.5              six
# 3           audi       gas         four        99.8   66.2             four
# 4           audi       gas         four        99.4   66.4             five
# ..           ...       ...          ...         ...    ...              ...
# 200        volvo       gas         four       109.1   68.9             four
# 201        volvo       gas         four       109.1   68.8             four
# 202        volvo       gas         four       109.1   68.9              six
# 203        volvo    diesel         four       109.1   68.9              six
# 204        volvo       gas         four       109.1   68.9             four
#
# [205 rows x 6 columns]

# %% [markdown]
# #### 4. Filter

# %%
raw_data['make'] == 'audi'   # This is a boolean condition, returns True if condition is True else False.
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: make, Length: 205, dtype: bool

# %%
raw_data[raw_data['make'] == 'audi']
# Out:
#    symboling normalized-losses  make fuel-type aspiration num-of-doors  \
# 3          2               164  audi       gas        std         four
# 4          2               164  audi       gas        std         four
# 5          2                 ?  audi       gas        std          two
# 6          1               158  audi       gas        std         four
# 7          1                 ?  audi       gas        std         four
# 8          1               158  audi       gas      turbo         four
# 9          0                 ?  audi       gas      turbo          two
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3      sedan          fwd           front        99.8  ...          109
# 4      sedan          4wd           front        99.4  ...          136
# 5      sedan          fwd           front        99.8  ...          136
# 6      sedan          fwd           front       105.8  ...          136
# 7      wagon          fwd           front       105.8  ...          136
# 8      sedan          fwd           front       105.8  ...          131
# 9  hatchback          4wd           front        99.5  ...          131
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
# 5         mpfi  3.19    3.40               8.5        110      5500       19
# 6         mpfi  3.19    3.40               8.5        110      5500       19
# 7         mpfi  3.19    3.40               8.5        110      5500       19
# 8         mpfi  3.13    3.40               8.3        140      5500       17
# 9         mpfi  3.13    3.40               7.0        160      5500       16
#
#   highway-mpg  price
# 3          30  13950
# 4          22  17450
# 5          25  15250
# 6          25  17710
# 7          25  18920
# 8          20  23875
# 9          22      ?
#
# [7 rows x 26 columns]

# %%
# Slicing dataframe using multiple condition.
raw_data[(raw_data['make'] == 'toyota') & (raw_data['body-style'] == 'sedan')]
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 156          0                91  toyota       gas        std         four
# 158          0                91  toyota    diesel        std         four
# 160          0                91  toyota       gas        std         four
# 162          0                91  toyota       gas        std         four
# 163          1               168  toyota       gas        std          two
# 165          1               168  toyota       gas        std          two
# 173         -1                65  toyota       gas        std         four
# 174         -1                65  toyota    diesel      turbo         four
# 176         -1                65  toyota       gas        std         four
# 180         -1                90  toyota       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 156      sedan          fwd           front        95.7  ...           98
# 158      sedan          fwd           front        95.7  ...          110
# 160      sedan          fwd           front        95.7  ...           98
# 162      sedan          fwd           front        95.7  ...           98
# 163      sedan          rwd           front        94.5  ...           98
# 165      sedan          rwd           front        94.5  ...           98
# 173      sedan          fwd           front       102.4  ...          122
# 174      sedan          fwd           front       102.4  ...          110
# 176      sedan          fwd           front       102.4  ...          122
# 180      sedan          rwd           front       104.5  ...          171
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 156         2bbl  3.19    3.03               9.0         70      4800
# 158          idi  3.27    3.35              22.5         56      4500
# 160         2bbl  3.19    3.03               9.0         70      4800
# 162         2bbl  3.19    3.03               9.0         70      4800
# 163         2bbl  3.19    3.03               9.0         70      4800
# 165         mpfi  3.24    3.08               9.4        112      6600
# 173         mpfi  3.31    3.54               8.7         92      4200
# 174          idi  3.27    3.35              22.5         73      4500
# 176         mpfi  3.31    3.54               8.7         92      4200
# 180         mpfi  3.27    3.35               9.2        156      5200
#
#     city-mpg highway-mpg  price
# 156       30          37   6938
# 158       34          36   7898
# 160       38          47   7738
# 162       28          34   9258
# 163       29          34   8058
# 165       26          29   9298
# 173       29          34   8948
# 174       30          33  10698
# 176       27          32  10898
# 180       20          24  15690
#
# [10 rows x 26 columns]

# %%
# Data display when either of two condition is True.
raw_data[(raw_data['make'] == 'toyota') | (raw_data['body-style'] == 'sedan')]
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            2               164   audi       gas        std         four
# 4            2               164   audi       gas        std         four
# 5            2                 ?   audi       gas        std          two
# 6            1               158   audi       gas        std         four
# 8            1               158   audi       gas      turbo         four
# ..         ...               ...    ...       ...        ...          ...
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
# 5        sedan          fwd           front        99.8  ...          136
# 6        sedan          fwd           front       105.8  ...          136
# 8        sedan          fwd           front       105.8  ...          131
# ..         ...          ...             ...         ...  ...          ...
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 3           mpfi  3.19    3.40              10.0        102      5500
# 4           mpfi  3.19    3.40               8.0        115      5500
# 5           mpfi  3.19    3.40               8.5        110      5500
# 6           mpfi  3.19    3.40               8.5        110      5500
# 8           mpfi  3.13    3.40               8.3        140      5500
# ..           ...   ...     ...               ...        ...       ...
# 200         mpfi  3.78    3.15               9.5        114      5400
# 201         mpfi  3.78    3.15               8.7        160      5300
# 202         mpfi  3.58    2.87               8.8        134      5500
# 203          idi  3.01    3.40              23.0        106      4800
# 204         mpfi  3.78    3.15               9.5        114      5400
#
#     city-mpg highway-mpg  price
# 3         24          30  13950
# 4         18          22  17450
# 5         19          25  15250
# 6         19          25  17710
# 8         17          20  23875
# ..       ...         ...    ...
# 200       23          28  16845
# 201       19          25  19045
# 202       18          23  21485
# 203       26          27  22470
# 204       19          25  22625
#
# [118 rows x 26 columns]

# %% [markdown]
# #### 5. Sorting

# %%
raw_data['wheel-base'].sort_values()              # Sort by ascending order.
# Out:
# 31      86.6
# 30      86.6
# 18      88.4
# 0       88.6
# 1       88.6
#        ...
# 113    114.2
# 114    114.2
# 71     115.6
# 70     115.6
# 73     120.9
# Name: wheel-base, Length: 205, dtype: float64

# %%
raw_data['wheel-base'].sort_values(ascending=False)   # Sorting wheel-base by Descending Order
# Out:
# 73     120.9
# 71     115.6
# 70     115.6
# 114    114.2
# 113    114.2
#        ...
# 1       88.6
# 0       88.6
# 18      88.4
# 30      86.6
# 31      86.6
# Name: wheel-base, Length: 205, dtype: float64

# %%
raw_data.sort_values(by = 'engine-size')   # sort Dataframe by engine size,
# Out:
#     symboling normalized-losses           make fuel-type aspiration  \
# 18          2               121      chevrolet       gas        std
# 57          3               150          mazda       gas        std
# 55          3               150          mazda       gas        std
# 56          3               150          mazda       gas        std
# 32          1               101          honda       gas        std
# ..        ...               ...            ...       ...        ...
# 48          0                 ?         jaguar       gas        std
# 47          0               145         jaguar       gas        std
# 74          1                 ?  mercedes-benz       gas        std
# 73          0                 ?  mercedes-benz       gas        std
# 49          0                 ?         jaguar       gas        std
#
#    num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 18          two  hatchback          fwd           front        88.4  ...
# 57          two  hatchback          rwd           front        95.3  ...
# 55          two  hatchback          rwd           front        95.3  ...
# 56          two  hatchback          rwd           front        95.3  ...
# 32          two  hatchback          fwd           front        93.7  ...
# ..          ...        ...          ...             ...         ...  ...
# 48         four      sedan          rwd           front       113.0  ...
# 47         four      sedan          rwd           front       113.0  ...
# 74          two    hardtop          rwd           front       112.0  ...
# 73         four      sedan          rwd           front       120.9  ...
# 49          two      sedan          rwd           front       102.0  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 18           61         2bbl  2.91    3.03               9.5         48
# 57           70         4bbl     ?       ?               9.4        101
# 55           70         4bbl     ?       ?               9.4        101
# 56           70         4bbl     ?       ?               9.4        101
# 32           79         1bbl  2.91    3.07              10.1         60
# ..          ...          ...   ...     ...               ...        ...
# 48          258         mpfi  3.63    4.17               8.1        176
# 47          258         mpfi  3.63    4.17               8.1        176
# 74          304         mpfi  3.80    3.35               8.0        184
# 73          308         mpfi  3.80    3.35               8.0        184
# 49          326         mpfi  3.54    2.76              11.5        262
#
#     peak-rpm city-mpg highway-mpg  price
# 18      5100       47          53   5151
# 57      6000       17          23  13645
# 55      6000       17          23  10945
# 56      6000       17          23  11845
# 32      5500       38          42   5399
# ..       ...      ...         ...    ...
# 48      4750       15          19  35550
# 47      4750       15          19  32250
# 74      4500       14          16  45400
# 73      4500       14          16  40960
# 49      5000       13          17  36000
#
# [205 rows x 26 columns]

# %%
raw_data.sort_values(by = ['make','engine-size']).head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# 13          0               188          bmw       gas        std
# 14          1                 ?          bmw       gas        std
# 15          0                 ?          bmw       gas        std
# 16          0                 ?          bmw       gas        std
# 17          0                 ?          bmw       gas        std
# 18          2               121    chevrolet       gas        std
# 19          1                98    chevrolet       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1           two  convertible          rwd           front        88.6  ...
# 2           two    hatchback          rwd           front        94.5  ...
# 3          four        sedan          fwd           front        99.8  ...
# 8          four        sedan          fwd           front       105.8  ...
# 9           two    hatchback          4wd           front        99.5  ...
# 4          four        sedan          4wd           front        99.4  ...
# 5           two        sedan          fwd           front        99.8  ...
# 6          four        sedan          fwd           front       105.8  ...
# 7          four        wagon          fwd           front       105.8  ...
# 10          two        sedan          rwd           front       101.2  ...
# 11         four        sedan          rwd           front       101.2  ...
# 12          two        sedan          rwd           front       101.2  ...
# 13         four        sedan          rwd           front       101.2  ...
# 14         four        sedan          rwd           front       103.5  ...
# 15         four        sedan          rwd           front       103.5  ...
# 16          two        sedan          rwd           front       103.5  ...
# 17         four        sedan          rwd           front       110.0  ...
# 18          two    hatchback          fwd           front        88.4  ...
# 19          two    hatchback          fwd           front        94.5  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0           130         mpfi  3.47    2.68               9.0        111
# 1           130         mpfi  3.47    2.68               9.0        111
# 2           152         mpfi  2.68    3.47               9.0        154
# 3           109         mpfi  3.19    3.40              10.0        102
# 8           131         mpfi  3.13    3.40               8.3        140
# 9           131         mpfi  3.13    3.40               7.0        160
# 4           136         mpfi  3.19    3.40               8.0        115
# 5           136         mpfi  3.19    3.40               8.5        110
# 6           136         mpfi  3.19    3.40               8.5        110
# 7           136         mpfi  3.19    3.40               8.5        110
# 10          108         mpfi  3.50    2.80               8.8        101
# 11          108         mpfi  3.50    2.80               8.8        101
# 12          164         mpfi  3.31    3.19               9.0        121
# 13          164         mpfi  3.31    3.19               9.0        121
# 14          164         mpfi  3.31    3.19               9.0        121
# 15          209         mpfi  3.62    3.39               8.0        182
# 16          209         mpfi  3.62    3.39               8.0        182
# 17          209         mpfi  3.62    3.39               8.0        182
# 18           61         2bbl  2.91    3.03               9.5         48
# 19           90         2bbl  3.03    3.11               9.6         70
#
#     peak-rpm city-mpg highway-mpg  price
# 0       5000       21          27  13495
# 1       5000       21          27  16500
# 2       5000       19          26  16500
# 3       5500       24          30  13950
# 8       5500       17          20  23875
# 9       5500       16          22      ?
# 4       5500       18          22  17450
# 5       5500       19          25  15250
# 6       5500       19          25  17710
# 7       5500       19          25  18920
# 10      5800       23          29  16430
# 11      5800       23          29  16925
# 12      4250       21          28  20970
# 13      4250       21          28  21105
# 14      4250       20          25  24565
# 15      5400       16          22  30760
# 16      5400       16          22  41315
# 17      5400       15          20  36880
# 18      5100       47          53   5151
# 19      5400       38          43   6295
#
# [20 rows x 26 columns]

# %%
# 'make' = sort 'make' by descending order, 'engine-size' by ascending order.
raw_data.sort_values(by = ['make','engine-size'], ascending = [False,True]).head(10)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 198         -2               103  volvo       gas      turbo         four
# 199         -1                74  volvo       gas      turbo         four
# 194         -2               103  volvo       gas        std         four
# 195         -1                74  volvo       gas        std         four
# 196         -2               103  volvo       gas        std         four
# 197         -1                74  volvo       gas        std         four
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 204         -1                95  volvo       gas      turbo         four
# 203         -1                95  volvo    diesel      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 198      sedan          rwd           front       104.3  ...          130
# 199      wagon          rwd           front       104.3  ...          130
# 194      sedan          rwd           front       104.3  ...          141
# 195      wagon          rwd           front       104.3  ...          141
# 196      sedan          rwd           front       104.3  ...          141
# 197      wagon          rwd           front       104.3  ...          141
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 204      sedan          rwd           front       109.1  ...          141
# 203      sedan          rwd           front       109.1  ...          145
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 198         mpfi  3.62    3.15               7.5        162      5100
# 199         mpfi  3.62    3.15               7.5        162      5100
# 194         mpfi  3.78    3.15               9.5        114      5400
# 195         mpfi  3.78    3.15               9.5        114      5400
# 196         mpfi  3.78    3.15               9.5        114      5400
# 197         mpfi  3.78    3.15               9.5        114      5400
# 200         mpfi  3.78    3.15               9.5        114      5400
# 201         mpfi  3.78    3.15               8.7        160      5300
# 204         mpfi  3.78    3.15               9.5        114      5400
# 203          idi  3.01    3.40              23.0        106      4800
#
#     city-mpg highway-mpg  price
# 198       17          22  18420
# 199       17          22  18950
# 194       23          28  12940
# 195       23          28  13415
# 196       24          28  15985
# 197       24          28  16515
# 200       23          28  16845
# 201       19          25  19045
# 204       19          25  22625
# 203       26          27  22470
#
# [10 rows x 26 columns]

# %%
# show all unique values of makers'
raw_data['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
# value_counts() show frequency of each category.
raw_data['make'].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %% [markdown]
# #### 6. Filter & Query
#     * filter() method is primarily used for subset the rows and columns of DataFrame.

# %%
raw_data.filter(like = 'num')
# Out:
#     num-of-doors num-of-cylinders
# 0            two             four
# 1            two             four
# 2            two              six
# 3           four             four
# 4           four             five
# ..           ...              ...
# 200         four             four
# 201         four             four
# 202         four              six
# 203         four              six
# 204         four             four
#
# [205 rows x 2 columns]

# %%
# slicing rows by row labels & axis = 0 (rowwise)
raw_data.filter(items = [0 , 2, 3, 5, 6, 8, 9, 10], axis = 0)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 2           two    hatchback          rwd           front        94.5  ...
# 3          four        sedan          fwd           front        99.8  ...
# 5           two        sedan          fwd           front        99.8  ...
# 6          four        sedan          fwd           front       105.8  ...
# 8          four        sedan          fwd           front       105.8  ...
# 9           two    hatchback          4wd           front        99.5  ...
# 10          two        sedan          rwd           front       101.2  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0           130         mpfi  3.47    2.68               9.0        111
# 2           152         mpfi  2.68    3.47               9.0        154
# 3           109         mpfi  3.19    3.40              10.0        102
# 5           136         mpfi  3.19    3.40               8.5        110
# 6           136         mpfi  3.19    3.40               8.5        110
# 8           131         mpfi  3.13    3.40               8.3        140
# 9           131         mpfi  3.13    3.40               7.0        160
# 10          108         mpfi  3.50    2.80               8.8        101
#
#     peak-rpm city-mpg highway-mpg  price
# 0       5000       21          27  13495
# 2       5000       19          26  16500
# 3       5500       24          30  13950
# 5       5500       19          25  15250
# 6       5500       19          25  17710
# 8       5500       17          20  23875
# 9       5500       16          22      ?
# 10      5800       23          29  16430
#
# [8 rows x 26 columns]

# %%
raw_data.filter(regex = '^e')    # slicing column by ^ which indicates start of column name.
# Out:
#     engine-location engine-type  engine-size
# 0             front        dohc          130
# 1             front        dohc          130
# 2             front        ohcv          152
# 3             front         ohc          109
# 4             front         ohc          136
# ..              ...         ...          ...
# 200           front         ohc          141
# 201           front         ohc          141
# 202           front        ohcv          173
# 203           front         ohc          145
# 204           front         ohc          141
#
# [205 rows x 3 columns]

# %%
raw_data.query("make =='toyota' and `engine-size` >= 130")
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 167          2               134  toyota       gas        std          two
# 168          2               134  toyota       gas        std          two
# 169          2               134  toyota       gas        std          two
# 170          2               134  toyota       gas        std          two
# 171          2               134  toyota       gas        std          two
# 172          2               134  toyota       gas        std          two
# 178          3               197  toyota       gas        std          two
# 179          3               197  toyota       gas        std          two
# 180         -1                90  toyota       gas        std         four
# 181         -1                 ?  toyota       gas        std         four
#
#       body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 167      hardtop          rwd           front        98.4  ...          146
# 168      hardtop          rwd           front        98.4  ...          146
# 169    hatchback          rwd           front        98.4  ...          146
# 170      hardtop          rwd           front        98.4  ...          146
# 171    hatchback          rwd           front        98.4  ...          146
# 172  convertible          rwd           front        98.4  ...          146
# 178    hatchback          rwd           front       102.9  ...          171
# 179    hatchback          rwd           front       102.9  ...          171
# 180        sedan          rwd           front       104.5  ...          171
# 181        wagon          rwd           front       104.5  ...          161
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 167         mpfi  3.62    3.50               9.3        116      4800
# 168         mpfi  3.62    3.50               9.3        116      4800
# 169         mpfi  3.62    3.50               9.3        116      4800
# 170         mpfi  3.62    3.50               9.3        116      4800
# 171         mpfi  3.62    3.50               9.3        116      4800
# 172         mpfi  3.62    3.50               9.3        116      4800
# 178         mpfi  3.27    3.35               9.3        161      5200
# 179         mpfi  3.27    3.35               9.3        161      5200
# 180         mpfi  3.27    3.35               9.2        156      5200
# 181         mpfi  3.27    3.35               9.2        156      5200
#
#     city-mpg highway-mpg  price
# 167       24          30   8449
# 168       24          30   9639
# 169       24          30   9989
# 170       24          30  11199
# 171       24          30  11549
# 172       24          30  17669
# 178       20          24  16558
# 179       19          24  15998
# 180       20          24  15690
# 181       19          24  15750
#
# [10 rows x 26 columns]

# %% [markdown]
# #### 7. Handling Missing Values

# %%
import numpy as np

# %%
# replace '?' by 'nan' and update dataframe 
raw_data.replace('?', np.nan, inplace=True)

# %%
# Returns total missing values from each column name.
raw_data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# Display missing values %
raw_data.isnull().sum() / raw_data.shape[0] * 100
# Out:
# symboling             0.00000
# normalized-losses    20.00000
# make                  0.00000
# fuel-type             0.00000
# aspiration            0.00000
# num-of-doors          0.97561
# body-style            0.00000
# drive-wheels          0.00000
# engine-location       0.00000
# wheel-base            0.00000
# length                0.00000
# width                 0.00000
# height                0.00000
# curb-weight           0.00000
# engine-type           0.00000
# num-of-cylinders      0.00000
# engine-size           0.00000
# fuel-system           0.00000
# bore                  1.95122
# stroke                1.95122
# compression-ratio     0.00000
# horsepower            0.97561
# peak-rpm              0.97561
# city-mpg              0.00000
# highway-mpg           0.00000
# price                 1.95122
# dtype: float64

# %%
# axis = 1 , Drop columns by using column name.
raw_data.drop(['symboling','normalized-losses'], axis = 1, inplace=True)

# %%
raw_data['price'].dtype
# Out:
# dtype('O')

# %%
raw_data['price'] = raw_data['price'].astype('float64')

# %%
vehicle_df = raw_data.copy()

# %%
vehicle_df['price'].median()
# Out:
# 10295.0

# %%
# fill missing values by mean of 'price'
vehicle_df['price'] = vehicle_df['price'].fillna(vehicle_df['price'].median())

# %%
# drop missing rows from all columns
vehicle_df.dropna(inplace=True)

# %%
vehicle_df.isnull().sum()
# Out:
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# #### 8. Drop Duplicate Rows
#     * Drop duplicate values

# %%
vehicle_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 197, dtype: bool

# %%
# select random sample from dataframe using frac=0.05 (5%) or n = num of samples
sample_df = vehicle_df.sample(frac = 0.05)

# %%
vehicle_df1 = pd.concat([vehicle_df, sample_df], ignore_index=True)

# %%
vehicle_df1[vehicle_df1.duplicated()]
# Out:
#               make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 197           saab       gas        std         four      sedan          fwd
# 198  mercedes-benz       gas        std          two    hardtop          rwd
# 199         nissan       gas        std         four  hatchback          fwd
# 200       plymouth       gas        std          two  hatchback          fwd
# 201         toyota       gas        std         four      sedan          fwd
# 202         nissan       gas        std         four      sedan          fwd
# 203         toyota    diesel        std         four  hatchback          fwd
# 204          volvo    diesel      turbo         four      sedan          rwd
# 205           audi       gas        std          two      sedan          fwd
# 206         toyota       gas        std          two  hatchback          rwd
#
#     engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 197           front        99.1   186.6   66.5  ...          121         mpfi
# 198           front       112.0   199.2   72.0  ...          304         mpfi
# 199           front        97.2   173.4   65.2  ...          120         2bbl
# 200           front        93.7   157.3   63.8  ...           90         2bbl
# 201           front       102.4   175.6   66.5  ...          122         mpfi
# 202           front       100.4   181.7   66.5  ...          181         mpfi
# 203           front        95.7   166.3   64.4  ...          110          idi
# 204           front       109.1   188.8   68.9  ...          145          idi
# 205           front        99.8   177.3   66.3  ...          136         mpfi
# 206           front        94.5   168.7   64.0  ...           98         mpfi
#
#      bore stroke  compression-ratio horsepower peak-rpm city-mpg  highway-mpg  \
# 197  3.54   3.07                9.3        110     5250       21           28
# 198  3.80   3.35                8.0        184     4500       14           16
# 199  3.33   3.47                8.5         97     5200       27           34
# 200  2.97   3.23                9.4         68     5500       37           41
# 201  3.31   3.54                8.7         92     4200       27           32
# 202  3.43   3.27                9.0        152     5200       17           22
# 203  3.27   3.35               22.5         56     4500       38           47
# 204  3.01   3.40               23.0        106     4800       26           27
# 205  3.19   3.40                8.5        110     5500       19           25
# 206  3.24   3.08                9.4        112     6600       26           29
#
#        price
# 197  12170.0
# 198  45400.0
# 199   8949.0
# 200   5572.0
# 201  10898.0
# 202  13499.0
# 203   7788.0
# 204  22470.0
# 205  15250.0
# 206   9538.0
#
# [10 rows x 24 columns]

# %%
vehicle_df1.drop_duplicates(inplace=True)   # drop all duplicates rows from DataFrame.

# %% [markdown]
# #### 9. Group By
#     * Used for aggregate operations.

# %%
vehicle_df1.groupby('make')['price'].mean()
# Out:
# make
# alfa-romero      15498.333333
# audi             16778.571429
# bmw              26118.750000
# chevrolet         6007.000000
# dodge             7790.125000
# honda             8184.692308
# isuzu             9605.750000
# jaguar           34600.000000
# mazda             9852.000000
# mercedes-benz    33647.000000
# mercury          16503.000000
# mitsubishi        9239.769231
# nissan           10415.666667
# peugot           15489.090909
# plymouth          7963.428571
# porsche          27179.400000
# saab             15223.333333
# subaru            8541.250000
# toyota            9885.812500
# volkswagen       10077.500000
# volvo            18063.181818
# Name: price, dtype: float64

# %%
vehicle_df1.groupby('make')[['city-mpg','price']].mean()
# Out:
#                 city-mpg         price
# make
# alfa-romero    20.333333  15498.333333
# audi           18.857143  16778.571429
# bmw            19.375000  26118.750000
# chevrolet      41.000000   6007.000000
# dodge          28.500000   7790.125000
# honda          30.384615   8184.692308
# isuzu          31.000000   9605.750000
# jaguar         14.333333  34600.000000
# mazda          27.833333   9852.000000
# mercedes-benz  18.500000  33647.000000
# mercury        19.000000  16503.000000
# mitsubishi     24.923077   9239.769231
# nissan         27.000000  10415.666667
# peugot         22.454545  15489.090909
# plymouth       28.142857   7963.428571
# porsche        17.400000  27179.400000
# saab           20.333333  15223.333333
# subaru         26.333333   8541.250000
# toyota         27.500000   9885.812500
# volkswagen     28.583333  10077.500000
# volvo          21.181818  18063.181818

# %%
vehicle_df1.groupby('make')[['city-mpg','price']].max().sort_values(by = 'price', ascending = False)
# Out:
#                city-mpg    price
# make
# mercedes-benz        22  45400.0
# bmw                  23  41315.0
# porsche              19  37028.0
# jaguar               15  36000.0
# audi                 24  23875.0
# volvo                26  22625.0
# nissan               45  19699.0
# saab                 21  18620.0
# mazda                31  18344.0
# peugot               28  18150.0
# toyota               38  17669.0
# mercury              19  16503.0
# alfa-romero          21  16500.0
# mitsubishi           37  14869.0
# volkswagen           37  13845.0
# dodge                37  12964.0
# honda                49  12945.0
# plymouth             37  12764.0
# subaru               32  11694.0
# isuzu                38  11048.0
# chevrolet            47   6575.0

# %% [markdown]
# #### 10. apply()
#     * Used to apply() function to modify the column values.

# %%
vehicle_df1['Dimension'] = vehicle_df1.apply(lambda row : row['length'] * row['width'], axis = 1)

# %%
vehicle_df1.head(3)
# Out:
#           make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
#
#   engine-location  wheel-base  length  width  ...  fuel-system  bore stroke  \
# 0           front        88.6   168.8   64.1  ...         mpfi  3.47   2.68
# 1           front        88.6   168.8   64.1  ...         mpfi  3.47   2.68
# 2           front        94.5   171.2   65.5  ...         mpfi  2.68   3.47
#
#   compression-ratio  horsepower peak-rpm city-mpg highway-mpg    price  \
# 0               9.0         111     5000       21          27  13495.0
# 1               9.0         111     5000       21          27  16500.0
# 2               9.0         154     5000       19          26  16500.0
#
#   Dimension
# 0  10820.08
# 1  10820.08
# 2  11213.60
#
# [3 rows x 25 columns]

# %% [markdown]
# #### 11. set & reset index

# %%
# Sample data
city = {
    'United States': 75708,
    'Germany': 47000,
    'Japan': 42444,
    'India': 2200,
    'Brazil': 10200,
    'China': 12500,
    'Australia': 75000,
    'Canada': 55000,
    'United Kingdom': 47000,
    'France': 43000
}
# Create a Pandas Series
gdp_per_capita_series = pd.Series(city)
print(gdp_per_capita_series)
# Out:
# United States     75708
# Germany           47000
# Japan             42444
# India              2200
# Brazil            10200
# China             12500
# Australia         75000
# Canada            55000
# United Kingdom    47000
# France            43000
# dtype: int64

# %%
city_gdp = pd.DataFrame(gdp_per_capita_series, columns=['gdp_per_capita'])

# %%
city_gdp
# Out:
#                 gdp_per_capita
# United States            75708
# Germany                  47000
# Japan                    42444
# India                     2200
# Brazil                   10200
# China                    12500
# Australia                75000
# Canada                   55000
# United Kingdom           47000
# France                   43000

# %%
city_gdp = city_gdp.reset_index()
city_gdp
# Out:
#             index  gdp_per_capita
# 0   United States           75708
# 1         Germany           47000
# 2           Japan           42444
# 3           India            2200
# 4          Brazil           10200
# 5           China           12500
# 6       Australia           75000
# 7          Canada           55000
# 8  United Kingdom           47000
# 9          France           43000

# %%
city_gdp.set_index('index')
# Out:
#                 gdp_per_capita
# index
# United States            75708
# Germany                  47000
# Japan                    42444
# India                     2200
# Brazil                   10200
# China                    12500
# Australia                75000
# Canada                   55000
# United Kingdom           47000
# France                   43000

# %% [markdown]
# #### 12. Pivot Table

# %%
vehicle_df1.pivot_table(values='price', index = 'drive-wheels', columns='body-style', aggfunc='mean')
# Out:
# body-style    convertible       hardtop     hatchback         sedan  \
# drive-wheels
# 4wd                   NaN           NaN   8949.000000  12647.333333
# fwd               11595.0   8249.000000   8365.166667   9834.290909
# rwd               23949.6  24202.714286  14419.666667  21711.833333
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd           10061.181818
# rwd           16994.222222

# %%
vehicle_df1.pivot_table(values='price', index = ['drive-wheels','engine-location'], 
                        columns='body-style', aggfunc='mean')
# Out:
# body-style                    convertible  hardtop     hatchback  \
# drive-wheels engine-location
# 4wd          front                    NaN      NaN   8949.000000
# fwd          front                11595.0   8249.0   8365.166667
# rwd          front                20680.0  20572.6  14419.666667
#              rear                 37028.0  33278.0           NaN
#
# body-style                           sedan         wagon
# drive-wheels engine-location
# 4wd          front            12647.333333   9095.750000
# fwd          front             9834.290909  10061.181818
# rwd          front            21711.833333  16994.222222
#              rear                      NaN           NaN

# %% [markdown]
# #### 13. Merge

# %%
# Series with country names and GDP per capita
df_series1 = pd.Series({'United States': 75708,'Germany': 47000,'Japan': 42444,'India': 2200,'Brazil': 10200
                }, name='GDP_Per_Capita')

# Series with country names and population
df_series2 = pd.Series({'United States': 331000000,'Germany': 83700000,'Japan': 126000000,'India': 1390000000,
                 'Brazil': 213000000}, name = 'Population')

# %%
df1 = pd.DataFrame(df_series1).reset_index()

# %%
# rename existing column
df1.columns = ['Country','GDP_Per_Capita']

# %%
# rename existing column
df2 = pd.DataFrame(df_series2).reset_index()
df2.columns = ['Country','Population']

# %%
pd.merge(df1, df2, on='Country',how='inner')
# Out:
#          Country  GDP_Per_Capita  Population
# 0  United States           75708   331000000
# 1        Germany           47000    83700000
# 2          Japan           42444   126000000
# 3          India            2200  1390000000
# 4         Brazil           10200   213000000

# %%
pd.merge(df1, df2, on='Country',how='outer')
# Out:
#          Country  GDP_Per_Capita  Population
# 0         Brazil           10200   213000000
# 1        Germany           47000    83700000
# 2          India            2200  1390000000
# 3          Japan           42444   126000000
# 4  United States           75708   331000000

# %%
pd.merge(df1, df2, on='Country',how='left')
# Out:
#          Country  GDP_Per_Capita  Population
# 0  United States           75708   331000000
# 1        Germany           47000    83700000
# 2          Japan           42444   126000000
# 3          India            2200  1390000000
# 4         Brazil           10200   213000000

# %%
pd.merge(df1, df2, on='Country',how='right')
# Out:
#          Country  GDP_Per_Capita  Population
# 0  United States           75708   331000000
# 1        Germany           47000    83700000
# 2          Japan           42444   126000000
# 3          India            2200  1390000000
# 4         Brazil           10200   213000000

# %% [markdown]
# #### 14. CrossTab
#     * Cross Tabulation is pandas method to create contingency table, that shows the frequency distribution of attributes.

# %%
pd.crosstab(vehicle_df1['body-style'],vehicle_df1['num-of-doors'])
# Out:
# num-of-doors  four  two
# body-style
# convertible      0    6
# hardtop          0    8
# hatchback       10   55
# sedan           79   15
# wagon           24    0
